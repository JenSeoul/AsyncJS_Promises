# %% [markdown]
# <a href="https://colab.research.google.com/github/JenSeoul/AsyncJS_Promises/blob/main/n132a_intermediate_linear_algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://i.imgur.com/RDAD11M.png' width = '200' align = 'right'>
#
# ## *DATA SCIENCE / SECTION 1 / SPRINT 3 / NOTE 2*
#
# # 📝 Assignment

# %% [markdown]
# ## 1. 주어진 리스트에 대해서 평균, 분산, 표준편차를 구하는 함수를 작성해보세요. (`mean`같은 builtin function 제외)
# > 이후 다음 데이터 [243, 278, 184, 249, 207] 에 대해서 해당 함수를 사용한 결과를 보이세요.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

v = np.array([243,278,184,249,207])
v2 = np.array([88,89,83,112,104])


# 작성하세요
def mymean(v):
  v = np.array(v)
  return sum(v)/len(v)

# 작성하세요.
def myvar(v):
  mean = mymean(v)
  variance = np.square(v - mean).sum()/len(v)
  return variance

# 작성하세요.
def mystd(v):
  variance = myvar(v)
  return np.sqrt(variance)

# %%
res1 = mymean(v)
res2 = myvar(v)
res3 = mystd(v)

# %% [markdown]
# ## 2. 위에서 사용된 데이터와 다음 데이터의 공분산과, 상관계수를 구해보세요 [88, 89, 83, 112, 104]

# %%
#cov function 
def mycov(x,y):
  meanx = mymean(x)
  meany = mymean(y)
  sum = 0
  for i in range(0, len(x)):
        sum += ((x[i] - meanx) * (y[i] - meany))
  return sum/(len(x)-1)

#corr function 
def mycorr(x,y):
  cov = round(mycov(x,y),1)
  xs = np.std(x,ddof=1)
  ys = np.std(y,ddof=1)
  r = cov/(xs*ys)
  return r

# %%
#answer 
res4 = mycov(v,v2)
res5 = mycorr(v,v2)

# %% [markdown]
# ## 3. 다음 벡터들의 span과, 이가 의미하는 바를 설명하세요.
#
# \begin{align}
# g = \begin{bmatrix} 1 & 3 \end{bmatrix}
# \qquad
# h = \begin{bmatrix} 2 & 6 \end{bmatrix}
# \end{align}

# %%
# 이곳에 답안을 작성하시기 바랍니다
g = [1,3]
h = [2,6]
matrix1 = np.array([
          [1,2],
          [3,6]
])

#종속관계인지 확인 
det1 = np.linalg.det(matrix1)

#단위 벡터 
#g = [1,0]*1 + [0,1]*3
#h = [1,0]*2 + [0,1]*6
# g = 1*i + 3*j
# h = 2*i + 6*j

# %%
#g벡터와 h벡터는 종속관계이기 때문에 선형으로만 존재하고 (2*g - h = 0) span하지 않는다.따라서 span은 1(1차원만 표현가능)
res6 = 1

# %%
#3번문제 그래프로 확인 
plt.xlim(0, 6)          
plt.ylim(0, 6)

vg = np.array(g).copy()
vh = np.multiply(2, g)

axes = plt.gca()
x_vals = np.array(axes.get_xlim())
y_vals = np.array(axes.get_ylim())

plt.arrow(0, 0, vg[0], vg[1], linewidth = 1, head_width = .05, head_length = .05, color = 'red',alpha=1)
plt.arrow(0, 0, vh[0], vh[1], linewidth = 1, head_width = .05, head_length = .05, color = 'blue',alpha=0.5)

plt.title("Two vectors heading to the same direction")
plt.show()

# %% [markdown]
# ## 4. 다음 벡터들의 span과, 이가 의미하는 바를 설명하세요.
#
# \begin{align}
# l = \begin{bmatrix} 1 & 2 & 3 \end{bmatrix}
# \qquad
# m = \begin{bmatrix} -1 & 0 & 7 \end{bmatrix}
# \qquad
# n = \begin{bmatrix} 4 & 8  & 2\end{bmatrix}
# \end{align}

# %%
#4.l,m,n벡터들의 span 
matrix2 = np.array(
    [
     [1,2,3],
     [-1,0,7],
     [4,8,2]
    ]
)

# %%
#l,m,n 벡터들은 각각 독립적이며(np.linalg.matrix_rank(matrix2)=3) 이 독립적인 선들을 조합한 집합은 3차원의 공간을 만들어낸다. 
#span
res7 = int(matrix2.shape[1])
print(res7)
# Out:
# 3

# %%
l = matrix2[0]
m = matrix2[1]
n = matrix2[2]

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.quiver(0,0,0,l[0],l[1],l[2], color='r',label='l')
ax.quiver(0,0,0,m[0],m[1],m[2],  color='b', label='m')
ax.quiver(0,0,0,n[0],n[1],n[2], color='g',label='n')
ax.legend()
plt.show()

# %% [markdown]
# ## 5. 다음 매트릭스의 rank를 구하세요
#
# \begin{align}
# P = \begin{bmatrix}
# 0 & 2 & 5 \\
#  3 & 6 & 12 \\
# 3 & 2 & 2
# \end{bmatrix}
# \end{align}

# %%
# 이곳에 답안을 작성하시기 바랍니다
matrix3 = np.array(
    [
     [0,2,5],
     [3,6,12],
     [3,2,2]
    ]
)

#matrix3[1] == matrix3[2] + 2*matrix3[0]

res8 = np.linalg.matrix_rank(matrix3)
print(res8)
# Out:
# 2

# %%
a = matrix3[0]
b = matrix3[1]
c = matrix3[2]

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.quiver(0,0,0,a[0],a[1],a[2], color='r',label='a')
ax.quiver(0,0,0,b[0],b[1],b[2],  color='b', label='b')
ax.quiver(0,0,0,c[0],c[1],c[2], color='g',label='c')
ax.legend()
plt.show()

# %%
matrix3[1] == matrix3[2] + 2*matrix3[0]
# Out:
# array([ True,  True,  True])

# %% [markdown]
# # 🔥 도전과제
#
# 주어진 데이터 (x, y)에 대해서 `y = x` 라는 벡터에 대해 projection을 계산하는 함수를 작성하세요.
# - (x, y) 는 (0, 0) 에서 (x, y)로 가는 벡터라 가정합니다.
#
# 이후
#
# - 입력된 데이터를 파란색 선으로,
# - `y = x` 라는 벡터를 빨간색 선으로, 마지막으로
# - projection 된 선을 녹색 점선(dashed)으로 그래프에 그리세요.

# %%
v = [7, 4]
w = np.array([7,7])

# 채우세요.
def myProjection(v):
  v = np.array(v)
  w_norm = np.linalg.norm(w)    
  vprime = (np.dot(v, w) / np.dot(w, w)) * w
  return vprime

vprime = myProjection(v)

# %%
plt.figure(figsize = (7,7))
plt.xlim(0,7)          
plt.ylim(0,7)
plt.xticks(ticks=np.arange(0, 7, step=1))
plt.yticks(ticks=np.arange(0, 7, step=1))

vprime = myProjection(v)
x_minus_proj = vprime[0]-v[0]
y_minus_proj = vprime[1]-v[1]

axes = plt.gca()
plt.gca().set_aspect('equal')
x_vals = np.array(axes.get_xlim())
y_vals = x_vals

plt.arrow(0, 0, vprime[0], vprime[1],linewidth=5, linestyle = '--', color = 'green',alpha=0.8)
plt.arrow(0, 0, v[0], v[1], linewidth = 3, head_width = .05, head_length = .05, color = 'b')
plt.arrow(v[0], v[1],x_minus_proj, y_minus_proj, linewidth = 3, head_width = .05, head_length = .05, color = 'orange')
plt.arrow(0, 0,7, 7, linewidth = 3, head_width = .05, head_length = .05, color = 'red',alpha=0.5)

plt.grid()
plt.show()
